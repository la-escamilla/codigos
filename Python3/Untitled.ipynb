# %%
print 'hola'
# Out:
#   File "<ipython-input-1-c06c34d8896b>", line 1
#     print 'hola'
#                ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('hola')?

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

for ii in range(10):
    plt.scatter(ii,ii,c='r')
plt.show()

# %%
mnist = tf.keras.datasets.mnist

# %%
mnist
# Out:
# <module 'tensorflow_core.python.keras.api._v2.keras.datasets.mnist' from 'C:\\Users\\52811\\AppData\\Local\\Continuum\\anaconda2\\envs\\py36\\lib\\site-packages\\tensorflow_core\\python\\keras\\api\\_v2\\keras\\datasets\\mnist\\__init__.py'>

# %%
from numpy import linspace
Nbins_rho = 5
step_rho  = 1


ini_param = []
for ii in range(Nbins_rho):
    if linspace(0,3,Nbins_rho)[ii]<2.32:
        ini_param += [0.0]
    elif linspace(0,3,Nbins_rho)[ii]>2.32:
        ini_param += [-2.0]

# %%
ini_param
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c62d8b59ee52> in <module>
# ----> 1 ini_param
#
# NameError: name 'ini_param' is not defined

# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %% [markdown]
# # Lo de Humberto

# %%
import scipy.special as special
import numpy as np
import matplotlib.pyplot as plt
import math

x=np.linspace(0.0,30,100)
special.eval_genlaguerre(1,0,2)
special.sph_harm(1,2,3,3)

#n = 5 
#l = n-1
#m = np.linspace(-l,l,2*l+1)
a0 = 1

def Rnl(n,l,r):
    return (2/(n**2))*(np.sqrt(math.factorial(n-l-1)/math.factorial(n+l)))*((2*r/(n*a0))**l)*np.exp(-r/(n*a0))*special.eval_genlaguerre(n-l-1,2*l+1,2*r/n)


plt.plot(x,abs(Rnl(3,1,x)))
plt.plot(x,abs(Rnl(3,2,x)))
plt.plot(x,abs(Rnl(4,1,x)))

# %%
import scipy.special as special
import numpy as np
import matplotlib.pyplot as plt
import math
special.sph_harm(1,2,3,3)

m = 1
l = 0
n = 1

theta = np.linspace(0,2*np.pi,100)
ax = plt.subplot(111, projection='polar')
ax.plot(theta, abs(special.sph_harm(1,1,0,theta)))

# %%
ax = plt.subplot(111, projection='polar')
ax.plot(theta, abs(special.sph_harm(1,2,0,theta)))

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as axes3d

theta, phi = np.linspace(0,  np.pi, 40), np.linspace(0, 2*np.pi, 40)
THETA, PHI = np.meshgrid(theta, phi)
R = abs(special.sph_harm(0,1,THETA,PHI))
X = R * np.sin(PHI) * np.cos(THETA)
Y = R * np.sin(PHI) * np.sin(THETA)
Z = R * np.cos(PHI)
fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')
plot = ax.plot_surface(
    X, Y, Z, rstride=1, cstride=1, cmap=plt.get_cmap('jet'),
    linewidth=0, antialiased=False, alpha=0.5)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as axes3d

theta, phi = np.linspace(0,  np.pi, 40), np.linspace(0, 2*np.pi, 40)
THETA, PHI = np.meshgrid(theta, phi)
R = abs(special.sph_harm(1,2,THETA,PHI))
X = R * np.sin(PHI) * np.cos(THETA)
Y = R * np.sin(PHI) * np.sin(THETA)
Z = R * np.cos(PHI)
fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')
plot = ax.plot_surface(
    X, Y, Z, rstride=1, cstride=1, cmap=plt.get_cmap('jet'),
    linewidth=0, antialiased=False, alpha=0.5)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as axes3d

theta, phi = np.linspace(0,  np.pi, 40), np.linspace(0, 2*np.pi, 40)
THETA, PHI = np.meshgrid(theta, phi)
R = abs(special.sph_harm(0,1,THETA,PHI))
X = R * np.sin(PHI) * np.cos(THETA)
Y = R * np.sin(PHI) * np.sin(THETA)
Z = R * np.cos(PHI)
fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')
plot = ax.plot_surface(
    X, Y, Z, rstride=1, cstride=1, cmap=plt.get_cmap('jet'),
    linewidth=0, antialiased=False, alpha=0.5)

plt.show()

# %%
from sklearn import linear_model

# %%
'''
==============
3D scatterplot
==============

Demonstration of a basic scatterplot in 3D.
'''

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np


def randrange(n, vmin, vmax):
    '''
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    '''
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for c, m, zlow, zhigh in [('r', 'o', 0, 2), ('b', '^', 0, 2)]:
    xs = randrange(n, 0, 1)
    ys = randrange(n, 0, 1)
    zs = randrange(n, zlow, zhigh)
    ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

n = 1000

xs = np.random.rand(n, 1)
ys = np.random.rand(n, 1)
zs = np.random.rand(n, 1)*2
ax.scatter(xs, ys, zs)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
j=0

for jj in zs:
    if jj<1:
        j+=1
print(j)
# Out:
# 518

# %%
i=[]
n=500
sample=1000
for jj in range(sample):
    zs = np.random.rand(n, 1)*2
    j=0
    for ii in zs:
        if ii<1:
            j+=1
    i.append(j/n)
            

plt.hist(i,bins=30)
# Out:
# (array([  3.,   2.,   1.,   5.,   4.,   7.,  18.,  18.,  26.,  43.,  36.,
#          39.,  83.,  64.,  61., 102.,  85.,  79., 112.,  46.,  41.,  39.,
#          27.,  20.,  18.,  10.,   2.,   4.,   3.,   2.]),
#  array([0.428     , 0.43266667, 0.43733333, 0.442     , 0.44666667,
#         0.45133333, 0.456     , 0.46066667, 0.46533333, 0.47      ,
#         0.47466667, 0.47933333, 0.484     , 0.48866667, 0.49333333,
#         0.498     , 0.50266667, 0.50733333, 0.512     , 0.51666667,
#         0.52133333, 0.526     , 0.53066667, 0.53533333, 0.54      ,
#         0.54466667, 0.54933333, 0.554     , 0.55866667, 0.56333333,
#         0.568     ]),
#  <a list of 30 Patch objects>)

# %%
u1 = np.sqrt(-2*np.log(xs))*np.sin(2*np.pi*ys)
u2 = np.sqrt(-2*np.log(xs))*np.cos(2*np.pi*ys)

# %%
plt.scatter(u1,u2)

# %%
plt.scatter(xs,ys)

# %%
np.random.random
# Out:
# array([[0.21938561, 0.58821846, 0.66228761],
#        [0.75375638, 0.62116655, 0.48954241],
#        [0.97859028, 0.81633684, 0.6596696 ]])

# %%
#Combinacion de todo lo anterior en una sola

import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from scipy.misc import derivative
from fgivenx import plot_contours, samples_from_getdist_chains

#en forma de funcion pa que sea mas rapido
#type_pars puede ser node o bin
#type_func puede ser eos o rho
#derived puede ser none, rho_dot, pressure, hz, qz, om_diag

def fgivenx_recons(file_root,n_pars=0,type_pars='node',type_func='eos',zhao=False,fourytwox=True,derived='none'):
    
    if derived!='none':
        savestyle=derived+'_'+type_func+'_'
    else:
        savestyle=type_func+'_'
    style=type_func
    if fourytwox==True:
        style+='_4y2x'
        savestyle+='4y2x_'
    if type_pars=='node':
        style+='_nodal'
    elif type_pars=='bin':
        if fourytwox==True:
            style+='_bins'
        else:
            style+='_tanh'
    if n_pars!=0:
        style+='%d'%n_pars
        savestyle+='%d'%n_pars
    savestyle+= type_pars
    style+='_phy_'
    if zhao==True:
        style+='%s_corr+'%type_func
        savestyle+='_zhao'
    file_root += style+'Pantheon+CBAO+HD_nested_dynesty_multi'
    
    params=[]
    for ii in range(n_pars):
        params+=['zbin_%s'%type_func+str(ii)]
    params+=['Om']
    params+=['h']
    if fourytwox==True:
        samples, weights = samples_from_getdist_chains(['luis71','luis72','luis73','luis74','w72', 'w73','Om','h'], file_root)
    else:
        samples, weights = samples_from_getdist_chains(params, file_root)
        

    #bin
    def PPS_bin(r, theta):
        if fourytwox == False:
            samples = theta
            #z_i = np.linspace(0.0,3.0,len(theta-1))
            w = theta[0]
            n = 0
        def bines(w_2,w_1,z_2,z_1,eta):
            return (w_2-w_1)*(1+np.tanh((z_2-z_1)/eta))/2
        def rho(r):
            w_0 = theta[0]
            z_i = np.linspace(0.0,3.0,len(theta)-1)
            for jj in range(len(theta)-3):
                w_0 += bines(theta[jj+1],theta[jj],r,z_i[jj+1],0.15)
            return w_0
        if type_func=='rho':
            return rho(r)*(1-theta[-2])

    if derived!='none':
        z_ini = 0.001
        if derived == 'om_diag':
            z_ini = 0.1
        z = np.linspace(z_ini,2.999,100)
    elif derived == 'none':
        z = np.linspace(0,3,100)
        
    if type_func == 'rho':
        if type_pars == 'bin':
            if derived != 'none':
                cbar = plot_contours(PPS_bin, z, samples, weights=weights,contour_line_levels=[1,2], colors=plt.cm.Blues_r)
            else:    
                cbar = plot_contours(PPS_bin, z, samples, weights=weights,contour_line_levels=[1,2], colors=plt.cm.Greens_r)
    cbar = plt.colorbar(cbar,ticks=[0,1,2])
    cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$'])

    
    lcdm = np.empty(100)
    plt.plot(z,lcdm, linestyle='--', color='k')

    plt.rc('font', size=14)
    plt.xscale('linear')
    plt.xlabel(r'$z$')
    plt.tight_layout()
    plt.grid()
    #plt.savefig('figs_full_panth/'+savestyle+'_full_panth.pdf')
    plt.show()
    plt.clf()

# %%
etiquetas = [ 'rho_dot', 'pressure', 'hz', 'qz', 'om_diag']
#for ii in etiquetas:
fgivenx_recons(file_root=u'C:\\Users\\52811\\cosas_python\\SimpleMC-master\\chains_zhao_new\\',
                type_func='rho', n_pars=4, type_pars='bin', zhao=False, fourytwox=False, derived='none')
# Out:
# C:\Users\52811\cosas_python\SimpleMC-master\chains_zhao_new\rho_tanh4_phy_Pantheon+CBAO+HD_nested_dynesty_multi_1.txt
# Removed no burn in
# ...

# %%
np.linspace(0.0,3.0,4)
# Out:
# array([0., 1., 2., 3.])

# %%
import numpy as np
import matplotlib.pyplot as plt

y=np.linspace(0.0,3.0,100)
def rho_de(z, rho_0=1.,rho_1=0.5,rho_2=1.):
    return rho_0 + rho_1/(1+z) #+ rho_2

# %%
plt.plot(y,rho_de(y))

# %%
y=[[],[]]

# %%
y.append([[1],[1]])

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import pytorch
#
# ModuleNotFoundError: No module named 'pytorch'
