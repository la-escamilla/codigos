# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %pwd
# Out:
# u'C:\\Users\\52811\\cosas_python'

# %%
df = pd.read_csv('test_rho_igual_0_scalCls.dat',sep='\s+')
dg = pd.read_csv('test_rho_scalCls.dat',sep='\s+')
dh = pd.read_csv('test_rho_negativa_scalCls.dat',sep='\s+')

# %%
plt.loglog(df['#'], df['L'])
plt.loglog(dg['#'], dg['L'])
plt.loglog(dh['#'], dh['L'])

# %%
df2 = pd.read_csv('test_rho_igual_0_matterpower.dat',sep='\s+')
dg2 = pd.read_csv('test_rho_matterpower.dat',sep='\s+')
dh2 = pd.read_csv('test_rho_negativa_matterpower.dat',sep='\s+')

# %%
plt.loglog(df2['#'], df2['k/h'])
plt.loglog(dg2['#'], dg2['k/h'])
plt.loglog(dh2['#'], dh2['k/h'])
